# %% [markdown]
# <a href="https://colab.research.google.com/github/keymemory/DYC_Machine_Learning/blob/main/ML_day2_review(day1_or).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OR 게이트 구현해보기

# %%
import tensorflow as tf
tf.random.set_seed(777)

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import mse

# %% [markdown]
# 데이터 준비하기

# %%
# 데이터 준비하기
data = np.array([[0,0],[1,0],[0,1],[1,1]]) # OR 연산을 할 데이터
label = np.array([[0],[1],[1],[1]]) # 정답

# %% [markdown]
# 모델 구성하기

# %%
# 모델 구성하기
model = Sequential()
model.add(Dense(1, input_shape = (2, ), activation = 'linear')) # 단층 퍼셉트론을 구성

# %% [markdown]
# 모델 설정하기

# %%
# 모델 준비하기
model.compile(optimizer = SGD(), loss = mse, metrics = ['acc']) # list 형태로 평가지표를 전달

# %% [markdown]
# 모델 확인하기

# %%
model.summary()
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 학습 시키기

# %%
# 학습시키기
history = model.fit(data, label, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4290 - acc: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3602 - acc: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2956 - acc: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2349 - acc: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1779 - acc: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1242 - acc: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0738 - acc: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0264 - acc: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9819 - acc: 0.5000
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9399 - acc: 0.5000
# Epoch 11/500
# ...

# %% [markdown]
# 그림으로 표현하기

# %%
import matplotlib.pyplot as plt

his_dict = history.history
loss = his_dict['loss'] # 손실값

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'orange', label = 'train_loss')
ax1.set_title('train loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc'] # acc 정확도

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_accuracy')
ax2.set_title('train accuracy')
ax2.set_xlabel('epochs')
ax2.set_ylabel('accuracy')
ax2.legend()

plt.show()

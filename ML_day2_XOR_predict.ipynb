# %% [markdown]
# <a href="https://colab.research.google.com/github/keymemory/DYC_Machine_Learning/blob/main/ML_day2_XOR_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import mse

# 시드 설정
tf.random.set_seed(777)

# 데이터 준비하기
x = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# 모델 구성하기
model = Sequential()

# 단층 퍼셉트론 구성
model.add(Dense(1, input_shape = (2, ), activation = 'linear'))

# 모델 준비
model.compile(optimizer = SGD(), loss = mse, metrics = ['acc']) # list 형태로 평가지표를 전달합니다

# 학습시키기 
history = model.fit(x, y, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9969 - acc: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9642 - acc: 0.7500
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9334 - acc: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9043 - acc: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8770 - acc: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8512 - acc: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8270 - acc: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8041 - acc: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7825 - acc: 0.7500
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7621 - acc: 0.7500
# Epoch 11/500
# ...

# %%
# evaluate()
model.evaluate(x,y)

# predict()
preds = model.predict(x)
for a, b in zip(preds, y):
  print(f"예측값 {a} - 정답 {b}")
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2519 - acc: 0.5000
# 예측값 [0.48344818] - 정답 [0]
# 예측값 [0.5567965] - 정답 [1]
# 예측값 [0.43800855] - 정답 [1]
# 예측값 [0.51135683] - 정답 [0]

# %%
import matplotlib.pyplot as plt

his_dict = history.history
loss = his_dict['loss'] # 손실값

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'orange', label = 'train_loss')
ax1.set_title('train loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc'] # acc 정확도

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_accuracy')
ax2.set_title('train accuracy')
ax2.set_xlabel('epochs')
ax2.set_ylabel('accuracy')
ax2.legend()

plt.show()

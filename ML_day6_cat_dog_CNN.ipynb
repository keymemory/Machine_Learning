# %% [markdown]
# <a href="https://colab.research.google.com/github/keymemory/DYC_Machine_Learning/blob/main/ML_day6_cat_dog_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# google api를 통해 데이터 불러오기

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2020-07-29 01:41:19--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 74.125.142.128, 74.125.195.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   134MB/s    in 0.5s
#
# 2020-07-29 01:41:19 (134 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %% [markdown]
# 데이터 폴더 나누기

# %%
#압축 풀기
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
rootPath = '/tmp/cats_and_dogs_filtered'
train_dir = os.path.join(rootPath, 'train')
validation_dir = os.path.join(rootPath, 'validation')

# Directory with our training cat pictures
train_cats_dir = os.path.join(train_dir, 'cats')

# Directory with our training dog pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')

# Directory with our validation dog pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %% [markdown]
# 데이터 확인

# %%
train_cat_fnames = os.listdir(train_cats_dir)
print(train_cat_fnames[:10])

train_dog_fnames = os.listdir(train_dogs_dir)
train_dog_fnames.sort()
print(train_dog_fnames[:10])

print('total training cat images:', len(os.listdir(train_cats_dir)))
print('total training dog images:', len(os.listdir(train_dogs_dir)))
print('total validation cat images:', len(os.listdir(validation_cats_dir)))
print('total validation dog images:', len(os.listdir(validation_dogs_dir)))
# Out:
# ['cat.200.jpg', 'cat.446.jpg', 'cat.540.jpg', 'cat.946.jpg', 'cat.435.jpg', 'cat.729.jpg', 'cat.68.jpg', 'cat.959.jpg', 'cat.58.jpg', 'cat.354.jpg']
# ['dog.0.jpg', 'dog.1.jpg', 'dog.10.jpg', 'dog.100.jpg', 'dog.101.jpg', 'dog.102.jpg', 'dog.103.jpg', 'dog.104.jpg', 'dog.105.jpg', 'dog.106.jpg']
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500

# %% [markdown]
# 데이터 증식
# Data Argumentation

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

rootPath = '/tmp/cats_and_dogs_filtered'

imageGenerator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[.2, .2],
    horizontal_flip=True,
    validation_split=.1
)

trainGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'train'),
    target_size=(64, 64),
    subset='training'
)

validationGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'validation'),
    target_size=(64, 64),
    subset='validation'
)
# Out:
# Found 1800 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %% [markdown]
# 간단한 CNN 모델을 구성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

model = Sequential()

model.add(layers.InputLayer(input_shape=(64, 64, 3)))
model.add(layers.Conv2D(16, (3, 3), (1, 1), 'same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Conv2D(32, (3, 3), (1, 1), 'same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Conv2D(64, (3, 3), (1, 1), 'same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(2, activation='sigmoid'))

# %% [markdown]
# 모델 확인하기

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, './model.png', show_shapes=True)

# %% [markdown]
# 모델 설정하기

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy', 
    metrics=['acc'],
)

# %% [markdown]
# 모델 학습하기

# %%
epochs = 32
history = model.fit_generator(
    trainGen, 
    epochs=epochs,
    steps_per_epoch=trainGen.samples / epochs, 
    validation_data=validationGen,
    validation_steps=trainGen.samples / epochs,
)
# Out:
# WARNING:tensorflow:From <ipython-input-9-b67571541efc>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.5006WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 129ms/step - loss: 0.6931 - acc: 0.5006 - val_loss: 0.6934 - val_acc: 0.5000
# Epoch 2/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6958 - acc: 0.4983WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.6958 - acc: 0.4983 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 3/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6932 - acc: 0.4850WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.6932 - acc: 0.4850 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 4/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6933 - acc: 0.4950WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.6933 - acc: 0.4950 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 5/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6933 - acc: 0.4933WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 128ms/step - loss: 0.6933 - acc: 0.4933 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 6/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5022WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 127ms/step - loss: 0.6928 - acc: 0.5022 - val_loss: 0.6861 - val_acc: 0.5600
# Epoch 7/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6894 - acc: 0.5289WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.6894 - acc: 0.5289 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 8/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6934 - acc: 0.5022WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.6934 - acc: 0.5022 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 9/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.5033WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 128ms/step - loss: 0.6931 - acc: 0.5033 - val_loss: 0.6926 - val_acc: 0.5100
# Epoch 10/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6922 - acc: 0.5394WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 127ms/step - loss: 0.6922 - acc: 0.5394 - val_loss: 0.6906 - val_acc: 0.5000
# Epoch 11/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6908 - acc: 0.5294WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 129ms/step - loss: 0.6908 - acc: 0.5294 - val_loss: 0.6845 - val_acc: 0.5800
# Epoch 12/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6892 - acc: 0.5517WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.6892 - acc: 0.5517 - val_loss: 0.6921 - val_acc: 0.5500
# Epoch 13/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6906 - acc: 0.5578WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 128ms/step - loss: 0.6906 - acc: 0.5578 - val_loss: 0.6855 - val_acc: 0.5900
# Epoch 14/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6723 - acc: 0.5878WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 124ms/step - loss: 0.6723 - acc: 0.5878 - val_loss: 0.6659 - val_acc: 0.5900
# Epoch 15/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6622 - acc: 0.5961WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 124ms/step - loss: 0.6622 - acc: 0.5961 - val_loss: 0.6924 - val_acc: 0.5500
# Epoch 16/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6623 - acc: 0.6211WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 123ms/step - loss: 0.6623 - acc: 0.6211 - val_loss: 0.6573 - val_acc: 0.6100
# Epoch 17/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6452 - acc: 0.6456WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 127ms/step - loss: 0.6452 - acc: 0.6456 - val_loss: 0.6162 - val_acc: 0.6300
# Epoch 18/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6220 - acc: 0.6483WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 127ms/step - loss: 0.6220 - acc: 0.6483 - val_loss: 0.5925 - val_acc: 0.7200
# Epoch 19/32
# 57/56 [==============================] - ETA: 0s - loss: 0.6159 - acc: 0.6772WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.6159 - acc: 0.6772 - val_loss: 0.6482 - val_acc: 0.6400
# Epoch 20/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5920 - acc: 0.6789WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 131ms/step - loss: 0.5920 - acc: 0.6789 - val_loss: 0.5956 - val_acc: 0.7000
# Epoch 21/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5966 - acc: 0.6894WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 8s 132ms/step - loss: 0.5966 - acc: 0.6894 - val_loss: 0.5995 - val_acc: 0.6800
# Epoch 22/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5915 - acc: 0.6933WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 130ms/step - loss: 0.5915 - acc: 0.6933 - val_loss: 0.5969 - val_acc: 0.7400
# Epoch 23/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5712 - acc: 0.7128WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 131ms/step - loss: 0.5712 - acc: 0.7128 - val_loss: 0.5349 - val_acc: 0.7300
# Epoch 24/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5794 - acc: 0.7011WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 131ms/step - loss: 0.5794 - acc: 0.7011 - val_loss: 0.5303 - val_acc: 0.7100
# Epoch 25/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5598 - acc: 0.7128WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 8s 135ms/step - loss: 0.5598 - acc: 0.7128 - val_loss: 0.5203 - val_acc: 0.6900
# Epoch 26/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5676 - acc: 0.7100WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 8s 132ms/step - loss: 0.5676 - acc: 0.7100 - val_loss: 0.5523 - val_acc: 0.7600
# Epoch 27/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5544 - acc: 0.7244WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 129ms/step - loss: 0.5544 - acc: 0.7244 - val_loss: 0.5090 - val_acc: 0.7600
# Epoch 28/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5428 - acc: 0.7144WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 127ms/step - loss: 0.5428 - acc: 0.7144 - val_loss: 0.5584 - val_acc: 0.6900
# Epoch 29/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5471 - acc: 0.7344WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 128ms/step - loss: 0.5471 - acc: 0.7344 - val_loss: 0.5343 - val_acc: 0.7300
# Epoch 30/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5327 - acc: 0.7328WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 129ms/step - loss: 0.5327 - acc: 0.7328 - val_loss: 0.5135 - val_acc: 0.7500
# Epoch 31/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5487 - acc: 0.7256WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 128ms/step - loss: 0.5487 - acc: 0.7256 - val_loss: 0.5397 - val_acc: 0.7300
# Epoch 32/32
# 57/56 [==============================] - ETA: 0s - loss: 0.5362 - acc: 0.7206WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 56.25 batches). You may need to use the repeat() function when building your dataset.
# 57/56 [==============================] - 7s 126ms/step - loss: 0.5362 - acc: 0.7206 - val_loss: 0.4958 - val_acc: 0.7800

# %% [markdown]
# 학습과정 그리기

# %%
import matplotlib.pyplot as plt

his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] # 검증 데이터가 있는 경우 ‘val_’ 수식어가 붙습니다.

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %% [markdown]
# 모델 평가하기

# %%
model.evaluate_generator(validationGen)
# Out:
# [0.49379807710647583, 0.800000011920929]

# %% [markdown]
# 모델 예측

# %%
from tensorflow.keras.preprocessing.image import array_to_img
import numpy as np

cls_index = ['고양이', '개']

imgs = validationGen.next()
arr = imgs[0][0]
img = array_to_img(arr).resize((128, 128))
plt.imshow(img)
result = model.predict_classes(arr.reshape(1, 64, 64, 3))
result2 = model.predict(arr.reshape(1, 64, 64, 3))

print(result2)
print('예측: {}'.format(cls_index[result[0]]))
print('정답: {}'.format(cls_index[np.argmax(imgs[1][0])]))
# Out:
# [[0.68426436 0.3083655 ]]
# 예측: 고양이
# 정답: 고양이
